# %% [markdown]
# <a href="https://colab.research.google.com/github/smminhaz/SkillMorph/blob/main/function_calculate_sum_of_numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sum_to_n(n):
    return n * (n + 1) // 2
n = int(input("Enter a number: "))
print("Sum from 1 to", n, "is:", sum_to_n(n))
# Out:
# Enter a number: 6
# Sum from 1 to 6 is: 21
